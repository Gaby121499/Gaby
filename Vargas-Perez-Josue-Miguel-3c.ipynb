# %%
initiate = 0
secondat = 0
endli = 1
sum_x = 0
sum_y = 0
isx2 = 0
product = 0
number = 0
i=0
y1 = float(input(f"Give me the temperature : "))
print(" ")
print("If you want end the linear regression write End")
print(" ")

while initiate == 0:
    secondat = 0
    print(f"Give the value of the time: ")
    value1 = str(input())

    if value1 == "End":
        initiate = 1

    else:
        sumyv = float(value1)
        sum_x = sum_x + sumyv
        isx2 = isx2 + (sumyv ** 2)

        while secondat == 0:
            print(f"Give the value of the temperature :")
            yvalue = str(input()) 

            if yvalue == "End":
                print("only after temperature-")
                secondat = 0

            else:
                yvtotal = float(yvalue)
                sum_y = sum_y + yvtotal 
                product = product + (sumyv * yvtotal)
                secondat = 1
    number = number + 1
    endli = endli + 1


b1 = (((number-1)*(product)) - ((sum_x)*(sum_y))) / (((number-1)*(isx2)) - ((sum_x)**2))
b0 = ((sum_y) - ((b1)*(sum_x))) / (number-1)
eq1 = ( y1 - b0 ) / b1
final1 = ( 30 - b0 ) / b1
time = (30 - b0) / b1
hours = time // 3600
minutes = (time % 3600) // 60
seconds = (time % 3600) % 60
time1 = (y1 - b0) / b1
hours1 = time1 // 3600
minutes1 = (time1 % 3600) // 60
seconds1 = (time1 % 3600) % 60
print(" Y = " ,b0+b1,"+ X")
print(f"\nTime to reach {y1}°C: {hours1} hours, {minutes1} minutes, {seconds1} seconds")
print(f"\nTime to reach 30°C: {hours} hours, {minutes} minutes, {seconds} seconds")



#Linear regression 2


sclinear = 0
line2 = 0
ends2 = 1
sumx2 = 0
sumy2 = 0
isx22 = 0
product2 = 0
num2 = 0

y12 = float(input(" Give me the temperature 2: "))
print(" ")
print("To end the linear regression write End-data")
print(" ")

while sclinear == 0:
    line2 = 0
    print("Give me the time:")
    value2 = str(input())

    if value2 == "End-data":
        sclinear = 1

    else:
        sumyv2 = float(value2)
        sumx2 = sumx2 + sumyv2 
        isx22 = isx22 + (sumyv2 ** 2)

        while line2 == 0:
            print("Give the temperature:")
            yvalue2 = str(input())

            if yvalue2 == "End-data":
                print("Only in the x is able")
                line2 = 0

            else:
                yvtot2 = float(yvalue2)
                sumy2 = sumy2 + yvtot2 
                product2 = product2 + (sumyv2 * yvtot2)
                line2 = 1
    num2 = num2 + 1
    ends2 = ends2 + 1


a1 = (((num2-1)*(product2)) - ((sumx2)*(sumy2))) / (((num2-1)*(isx22)) - ((sumx2)**2))
a2 = ((sumy2) - ((a1)*(sumx2))) / (num2-1)
eqsc2 = ( y12 - a2 ) / a1     
final = ( 30 - a2 ) / a1
time12 = (30 - a2) / a1
hours12 = time12 // 3600
minutes12 = (time12 % 3600) // 60
seconds12 = (time12 % 3600) % 60
time2 = (y12 - a2) / a1
hours2 = time2 // 3600
minutes2 = (time2 % 3600) // 60
seconds2 = (time2 % 3600) % 60

print(" Y = " ,a2+a1,"+ X")
print(f"\nTime to reach {y12}°C: {hours2} hours, {minutes2} minutes, {seconds2} seconds")
print(f"\nTime to reach 30°C: {hours12} hours, {minutes12} minutes, {seconds12} seconds")

if final1<final:
     print("\nThe first device was the first in reache the temperature")
else:
     print("\nThe second device was the first in reach the required temperature")
# Out:
# Give me the temperature : 30
#
# If you want end the linear regression write End
#
# Give the value of the time:
# 0
# Give the value of the temperature :
# 20
# Give the value of the time:
# 30
# Give the value of the temperature :
# 20.1
# Give the value of the time:
# 60
# Give the value of the temperature :
# 20.1
# Give the value of the time:
# 90
# Give the value of the temperature :
# 20.3
# Give the value of the time:
# 120
# Give the value of the temperature :
# 20.3
# Give the value of the time:
# End
#  Y =  20.002666666666666 + X
#
# Time to reach 30.0°C: 1.0 hours, 2.0 minutes, 30.0 seconds
#
# Time to reach 30°C: 1.0 hours, 2.0 minutes, 30.0 seconds
#  Give me the temperature 2: 30
#
# To end the linear regression write End-data
#
# Give me the time:
# 0
# Give the temperature:
# 20
# Give me the time:
# 30
# Give the temperature:
# 20.1
# Give me the time:
# 60
# Give the temperature:
# 20.2
# Give me the time:
# 90
# Give the temperature:
# 20.2
# Give me the time:
# ...

# %%
End-data
